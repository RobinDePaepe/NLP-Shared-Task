# %%
 import pandas as pd

# transformer
from sklearn.base import BaseEstimator, TransformerMixin

# pipeline
from nltk.tokenize import word_tokenize
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import train_test_split, cross_val_predict, GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report

# %%
toefl = pd.read_csv('toefl11_trainingdata_features')
toefl = toefl.drop(['Unnamed: 0','Unnamed: 0.1'], axis= 1)

# %%
test = pd.read_csv('Featured_Data/test_features.csv')

# %%
class ItemSelector(BaseEstimator, TransformerMixin):
    def __init__(self, key):
        self.key = key
        
    def fit(self, x, y=None):
        return self
    
    def transform(self, data_dict):
        return data_dict[self.key]

# %% [markdown]
# ## NLI

# %%
#Pipeline
#define features and y 
y = toefl.drop(['Filename','text','POS','DEP', 'NER', 'prop_punct', 'prop_capwords', 'prop_capI','avg_sentlength'], axis = 1)
x = toefl.drop(['Filename', 'Language', 'Proficiency', 'NER', 'prop_capwords',], axis = 1)
X_train, X_dev, y_train, y_dev = train_test_split(x, y['Language'], test_size= 0.20)

# %%
numeric_features = ['prop_punct', 'avg_sentlength', 'prop_capI']
tfidfvect = TfidfVectorizer()
linsvm = LinearSVC()
#refit with best ranges
numfeat_pipe = Pipeline([
    ('selector', ItemSelector(key=numeric_features))
])

# pipe word n-grams
text_pipe = Pipeline([
    ('selector', ItemSelector(key='text')),
    ('vect', TfidfVectorizer(
        tokenizer=word_tokenize,
        analyzer='word',
        lowercase=True,
        ngram_range=(1,2)))
])

# pipe char n-grams
char_pipe = Pipeline([
    ('selector', ItemSelector(key="text")),
    ('vect', TfidfVectorizer(
        analyzer='char',
        lowercase=True,
        ngram_range=(2,4)))
])

# pipe POS n-grams
pos_pipe = Pipeline([
    ('selector', ItemSelector(key="POS")),
    ('vect', TfidfVectorizer(
        analyzer='word',
        lowercase=True,
        ngram_range=(1,3)))
])

# pipe complete
pipe = Pipeline([
    ('feats', FeatureUnion([
        ('numfeat_pipe', numfeat_pipe),
        ('text_pipe', text_pipe),
        ('char_pipe', char_pipe),
        ('pos_pipe', pos_pipe)
    ])),
    ('cls', linsvm)
])

# %%
# fit model
pipe.fit(X_train, y_train)
# Out:
# C:\Users\robin\anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# Pipeline(steps=[('feats',
#                  FeatureUnion(transformer_list=[('numfeat_pipe',
#                                                  Pipeline(steps=[('selector',
#                                                                   ItemSelector(key=['prop_punct',
#                                                                                     'avg_sentlength',
#                                                                                     'prop_capI']))])),
#                                                 ('text_pipe',
#                                                  Pipeline(steps=[('selector',
#                                                                   ItemSelector(key='text')),
#                                                                  ('vect',
#                                                                   TfidfVectorizer(ngram_range=(1,
#                                                                                                2),
#                                                                                   tokenizer=<function word_tokenize at 0x000001C57561CEE0>))])),
#                                                 ('char_pipe',
#                                                  Pipeline(steps=[('selector',
#                                                                   ItemSelector(key='text')),
#                                                                  ('vect',
#                                                                   TfidfVectorizer(analyzer='char',
#                                                                                   ngram_range=(2,
#                                                                                                4)))])),
#                                                 ('pos_pipe',
#                                                  Pipeline(steps=[('selector',
#                                                                   ItemSelector(key='POS')),
#                                                                  ('vect',
#                                                                   TfidfVectorizer(ngram_range=(1,
#                                                                                                3)))]))])),
#                 ('cls', LinearSVC())])

# %%
# prediction
y_dev_pred = pipe.predict(X_dev)

# accuracy
print(classification_report(y_dev, y_dev_pred))
# Out:
#               precision    recall  f1-score   support
#
#          ARA       0.83      0.77      0.80       211
#          DEU       0.82      0.95      0.88       192
#          FRA       0.81      0.86      0.84       191
#          HIN       0.71      0.70      0.70       208
#          ITA       0.83      0.86      0.84       195
#          JPN       0.82      0.77      0.79       208
#          KOR       0.78      0.80      0.79       211
#          SPA       0.79      0.68      0.73       200
#          TEL       0.77      0.80      0.78       200
#          TUR       0.85      0.84      0.84       186
#          ZHO       0.85      0.85      0.85       198
#
#     accuracy                           0.81      2200
#    macro avg       0.81      0.81      0.81      2200
# weighted avg       0.80      0.81      0.80      2200

# %%
test_predict_Language = pipe.predict(test)

# %%
test_predict_Language
# Out:
# array(['JPN', 'ARA', 'DEU', ..., 'TUR', 'TUR', 'DEU'], dtype=object)

# %%
test['Predicted_Language'] = test_predict_Language
test
# Out:
#       Unnamed: 0     Filename  \
# 0              0    10226.txt
# 1              1    10229.txt
# 2              2    10392.txt
# 3              3    10445.txt
# 4              4    10535.txt
# ...          ...          ...
# 1095        1095  1175383.txt
# 1096        1096  1175412.txt
# 1097        1097  1175488.txt
# 1098        1098  1175980.txt
# 1099        1099  1176184.txt
#
#                                                    text  \
# 0     I agree. Because if I had many academic subjec...
# 1     I DO NOT AGREE WITH THIS STATEMENT BECOUSE , N...
# 2     I am not quite sure about my oppinion on that ...
# 3     It is often said that young people's interest ...
# 4     In mordern society, students always face the d...
# ...                                                 ...
# 1095    There are heated disscussion about that youn...
# 1096  In my personal opinion young people do not spe...
# 1097  I believe that people who take risks are succe...
# 1098  With the rapid progress of time everything aro...
# 1099  Taking risks and trying new things have in com...
#
#                                                     POS  \
# 0     PRON VERB PUNCT SCONJ SCONJ PRON VERB ADJ ADJ ...
# 1     PRON VERB PART VERB ADP DET NOUN PROPN PUNCT D...
# 2     PRON VERB PART ADV ADJ ADP PRON NOUN ADP DET N...
# 3     PRON VERB ADV VERB SCONJ ADJ NOUN PART NOUN AD...
# 4     ADP ADJ NOUN PUNCT NOUN ADV VERB DET NOUN SCON...
# ...                                                 ...
# 1095  SPACE PRON VERB ADJ NOUN ADP DET ADJ NOUN VERB...
# 1096  ADP PRON ADJ NOUN ADJ NOUN VERB PART VERB ADJ ...
# 1097  PRON VERB SCONJ NOUN PRON VERB NOUN VERB ADJ C...
# 1098  ADP DET ADJ NOUN ADP NOUN PRON ADP PRON VERB V...
# 1099  VERB NOUN CCONJ VERB ADJ NOUN VERB ADP ADJ NUM...
#
#                                                     DEP  \
# 0     nsubj ROOT punct mark mark nsubj advcl amod am...
# 1     nsubj aux neg ROOT prep det compound pobj punc...
# 2     nsubj ROOT neg advmod acomp prep poss pobj pre...
# 3     nsubjpass auxpass advmod ROOT mark amod poss c...
# 4     prep amod pobj punct nsubj advmod ROOT det dob...
# ...                                                 ...
# 1095  dep expl ROOT amod attr prep mark amod nsubj p...
# 1096  prep poss amod pobj amod nsubj aux neg ROOT am...
# 1097  nsubj ROOT mark nsubj nsubj relcl dobj ccomp a...
# 1098  prep det amod pobj prep pobj nsubj prep pobj a...
# 1099  advcl dobj cc conj amod dobj conj prep amod nu...
#
#                                                     NER  prop_punct  \
# 0                                       [one, only one]    0.137255
# 1                                                    []    0.106667
# 2                         [First, one, one, first, one]    0.091743
# 3     [the Ministry of Education, Korea, 67%, 10 yea...    0.076923
# 4                            [one, daily, first, first]    0.084444
# ...                                                 ...         ...
# 1095                                         [MSN, ICQ]    0.128079
# 1096                                            [First]    0.091667
# 1097                                              [one]    0.034921
# 1098                                     [recent years]    0.103306
# 1099                                              [one]    0.116959
#
#       prop_capwords  avg_sentlength  prop_capwords_beginningsent  prop_capI  \
# 0          0.252874        8.700000                     1.000000   1.000000
# 1          0.904110       23.666667                     1.000000   1.000000
# 2          0.064433       16.166667                     1.000000   1.000000
# 3          0.079038       16.166667                     1.000000   1.000000
# 4          0.064516       20.200000                     1.000000   0.857143
# ...             ...             ...                          ...        ...
# 1095       0.016667       11.888889                     0.884615   1.000000
# 1096       0.068323       14.681818                     0.954545   1.000000
# 1097       0.039604       25.250000                     1.000000   1.000000
# 1098       0.015957       15.230769                     1.000000  -1.000000
# 1099       0.057239       19.800000                     1.000000   1.000000
#
#      Predicted_Language
# 0                   JPN
# 1                   ARA
# 2                   DEU
# 3                   JPN
# 4                   ZHO
# ...                 ...
# 1095                ZHO
# 1096                HIN
# 1097                TUR
# 1098                TUR
# 1099                DEU
#
# [1100 rows x 12 columns]

# %% [markdown]
# ## Proficiency

# %%
y = toefl.drop(['Filename','text','POS','DEP', 'NER', 'prop_punct', 'prop_capwords', 'prop_capI','avg_sentlength'], axis = 1)
x = toefl.drop(['Filename', 'Language', 'Proficiency', 'NER', 'prop_capwords','avg_sentlength'], axis = 1)
X_train, X_dev, y_train, y_dev = train_test_split(x, y['Proficiency'], test_size= 0.20)
# dropping avg_sent lenght as well

# %%
x
# Out:
#                                                     text  \
# 0      Some people might think that traveling in a gr...
# 1      IThe importance and popularity of travelling i...
# 2      It is an important decision, how to plan your ...
# 3      Some people believe that young people can enjo...
# 4      Travelling is  usually considered as good recr...
# ...                                                  ...
# 10995  Nowadays, more and more people go abroad,no ma...
# 10996  \tIn accomplishing something that is risky com...
# 10997  At the beginning of the 21st century, the incr...
# 10998  The number of cars in use across the world has...
# 10999        Many people think it is betters to have ...
#
#                                                      POS  \
# 0      DET NOUN VERB VERB SCONJ VERB ADP DET NOUN VER...
# 1      ADP NOUN CCONJ NOUN ADP VERB AUX ADV VERB PUNC...
# 2      PRON AUX DET ADJ NOUN PUNCT ADV PART VERB DET ...
# 3      DET NOUN VERB SCONJ ADJ NOUN VERB VERB NOUN AD...
# 4      PROPN AUX SPACE ADV VERB SCONJ ADJ NOUN SPACE ...
# ...                                                  ...
# 10995  ADV PUNCT ADJ CCONJ ADJ NOUN VERB ADV PUNCT AD...
# 10996  SPACE ADP VERB PRON DET AUX ADJ VERB DET NOUN ...
# 10997  ADP DET NOUN ADP DET ADJ NOUN PUNCT DET VERB N...
# 10998  DET NOUN ADP NOUN ADP NOUN ADP DET NOUN AUX AU...
# 10999  SPACE ADJ NOUN VERB PRON AUX NOUN PART AUX ADJ...
#
#                                                      DEP  prop_punct  \
# 0      det nsubj aux ROOT mark csubj prep det pobj ac...    0.073634
# 1      det nsubj cc conj prep pcomp aux advmod ROOT p...    0.052023
# 2      nsubj ROOT det amod attr punct advmod aux advc...    0.089330
# 3      det nsubj ROOT mark amod nsubj aux ccomp dobj ...    0.096059
# 4      nsubjpass auxpass  advmod ROOT prep amod pobj ...    0.048387
# ...                                                  ...         ...
# 10995  advmod punct amod cc conj nsubj ROOT advmod pu...    0.121294
# 10996   prep pcomp dobj nsubj relcl acomp ROOT det ns...    0.094148
# 10997  prep det pobj prep det amod pobj punct det amo...    0.070028
# 10998  det nsubj prep pobj prep pobj prep det pobj au...    0.090253
# 10999   amod nsubj ROOT nsubj ccomp attr aux xcomp co...    0.086687
#
#        prop_capI
# 0       1.000000
# 1       1.000000
# 2       0.800000
# 3       1.000000
# 4       0.000000
# ...          ...
# 10995   0.000000
# 10996   1.000000
# 10997   1.000000
# 10998   1.000000
# 10999   0.166667
#
# [11000 rows x 5 columns]

# %%
numeric_features = ['prop_punct', 'prop_capI']
tfidfvect = TfidfVectorizer()

linsvm = LinearSVC()
#refit with best ranges
numfeat_pipe = Pipeline([
    ('selector', ItemSelector(key=numeric_features))
])

# pipe word n-grams
text_pipe = Pipeline([
    ('selector', ItemSelector(key='text')),
    ('vect', TfidfVectorizer(
        tokenizer=word_tokenize,
        analyzer='word',
        lowercase=True,
        ngram_range=(1,2)))
])

# pipe char n-grams
char_pipe = Pipeline([
    ('selector', ItemSelector(key="text")),
    ('vect', TfidfVectorizer(
        analyzer='char',
        lowercase=True,
        ngram_range=(2,3)))
])

# pipe POS n-grams
pos_pipe = Pipeline([
    ('selector', ItemSelector(key="POS")),
    ('vect', TfidfVectorizer(
        analyzer='word',
        lowercase=True,
        ngram_range=(1,4)))
])

# pipe complete
pipe = Pipeline([
    ('feats', FeatureUnion([
        ('numfeat_pipe', numfeat_pipe),
        ('text_pipe', text_pipe),
        ('char_pipe', char_pipe),
        ('pos_pipe', pos_pipe)
    ])),
    ('cls', linsvm)
])

# %%
# fit model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('feats',
#                  FeatureUnion(transformer_list=[('numfeat_pipe',
#                                                  Pipeline(steps=[('selector',
#                                                                   ItemSelector(key=['prop_punct',
#                                                                                     'prop_capI']))])),
#                                                 ('text_pipe',
#                                                  Pipeline(steps=[('selector',
#                                                                   ItemSelector(key='text')),
#                                                                  ('vect',
#                                                                   TfidfVectorizer(ngram_range=(1,
#                                                                                                2),
#                                                                                   tokenizer=<function word_tokenize at 0x000001C57561CEE0>))])),
#                                                 ('char_pipe',
#                                                  Pipeline(steps=[('selector',
#                                                                   ItemSelector(key='text')),
#                                                                  ('vect',
#                                                                   TfidfVectorizer(analyzer='char',
#                                                                                   ngram_range=(2,
#                                                                                                3)))])),
#                                                 ('pos_pipe',
#                                                  Pipeline(steps=[('selector',
#                                                                   ItemSelector(key='POS')),
#                                                                  ('vect',
#                                                                   TfidfVectorizer(ngram_range=(1,
#                                                                                                4)))]))])),
#                 ('cls', LinearSVC())])

# %%
from sklearn.metrics import classification_report
# prediction
y_dev_pred = pipe.predict(X_dev)

# accuracy
print(classification_report(y_dev, y_dev_pred))
# Out:
#               precision    recall  f1-score   support
#
#         high       0.67      0.78      0.72       802
#          low       0.81      0.36      0.50       221
#       medium       0.73      0.73      0.73      1177
#
#     accuracy                           0.71      2200
#    macro avg       0.74      0.62      0.65      2200
# weighted avg       0.72      0.71      0.70      2200

# %%
test_predict_proficiency = pipe.predict(test)
test_predict_proficiency
# Out:
# array(['low', 'low', 'high', ..., 'high', 'medium', 'high'], dtype=object)

# %%
test['Predicted_Proficiency'] = test_predict_proficiency

# %%
test
# Out:
#       Unnamed: 0     Filename  \
# 0              0    10226.txt
# 1              1    10229.txt
# 2              2    10392.txt
# 3              3    10445.txt
# 4              4    10535.txt
# ...          ...          ...
# 1095        1095  1175383.txt
# 1096        1096  1175412.txt
# 1097        1097  1175488.txt
# 1098        1098  1175980.txt
# 1099        1099  1176184.txt
#
#                                                    text  \
# 0     I agree. Because if I had many academic subjec...
# 1     I DO NOT AGREE WITH THIS STATEMENT BECOUSE , N...
# 2     I am not quite sure about my oppinion on that ...
# 3     It is often said that young people's interest ...
# 4     In mordern society, students always face the d...
# ...                                                 ...
# 1095    There are heated disscussion about that youn...
# 1096  In my personal opinion young people do not spe...
# 1097  I believe that people who take risks are succe...
# 1098  With the rapid progress of time everything aro...
# 1099  Taking risks and trying new things have in com...
#
#                                                     POS  \
# 0     PRON VERB PUNCT SCONJ SCONJ PRON VERB ADJ ADJ ...
# 1     PRON VERB PART VERB ADP DET NOUN PROPN PUNCT D...
# 2     PRON VERB PART ADV ADJ ADP PRON NOUN ADP DET N...
# 3     PRON VERB ADV VERB SCONJ ADJ NOUN PART NOUN AD...
# 4     ADP ADJ NOUN PUNCT NOUN ADV VERB DET NOUN SCON...
# ...                                                 ...
# 1095  SPACE PRON VERB ADJ NOUN ADP DET ADJ NOUN VERB...
# 1096  ADP PRON ADJ NOUN ADJ NOUN VERB PART VERB ADJ ...
# 1097  PRON VERB SCONJ NOUN PRON VERB NOUN VERB ADJ C...
# 1098  ADP DET ADJ NOUN ADP NOUN PRON ADP PRON VERB V...
# 1099  VERB NOUN CCONJ VERB ADJ NOUN VERB ADP ADJ NUM...
#
#                                                     DEP  \
# 0     nsubj ROOT punct mark mark nsubj advcl amod am...
# 1     nsubj aux neg ROOT prep det compound pobj punc...
# 2     nsubj ROOT neg advmod acomp prep poss pobj pre...
# 3     nsubjpass auxpass advmod ROOT mark amod poss c...
# 4     prep amod pobj punct nsubj advmod ROOT det dob...
# ...                                                 ...
# 1095  dep expl ROOT amod attr prep mark amod nsubj p...
# 1096  prep poss amod pobj amod nsubj aux neg ROOT am...
# 1097  nsubj ROOT mark nsubj nsubj relcl dobj ccomp a...
# 1098  prep det amod pobj prep pobj nsubj prep pobj a...
# 1099  advcl dobj cc conj amod dobj conj prep amod nu...
#
#                                                     NER  prop_punct  \
# 0                                       [one, only one]    0.137255
# 1                                                    []    0.106667
# 2                         [First, one, one, first, one]    0.091743
# 3     [the Ministry of Education, Korea, 67%, 10 yea...    0.076923
# 4                            [one, daily, first, first]    0.084444
# ...                                                 ...         ...
# 1095                                         [MSN, ICQ]    0.128079
# 1096                                            [First]    0.091667
# 1097                                              [one]    0.034921
# 1098                                     [recent years]    0.103306
# 1099                                              [one]    0.116959
#
#       prop_capwords  avg_sentlength  prop_capwords_beginningsent  prop_capI  \
# 0          0.252874        8.700000                     1.000000   1.000000
# 1          0.904110       23.666667                     1.000000   1.000000
# 2          0.064433       16.166667                     1.000000   1.000000
# 3          0.079038       16.166667                     1.000000   1.000000
# 4          0.064516       20.200000                     1.000000   0.857143
# ...             ...             ...                          ...        ...
# 1095       0.016667       11.888889                     0.884615   1.000000
# 1096       0.068323       14.681818                     0.954545   1.000000
# 1097       0.039604       25.250000                     1.000000   1.000000
# 1098       0.015957       15.230769                     1.000000  -1.000000
# 1099       0.057239       19.800000                     1.000000   1.000000
#
#      Predicted_Language Predicted_Proficiency
# 0                   JPN                   low
# 1                   ARA                   low
# 2                   DEU                  high
# 3                   JPN                  high
# 4                   ZHO                  high
# ...                 ...                   ...
# 1095                ZHO                medium
# 1096                HIN                medium
# 1097                TUR                  high
# 1098                TUR                medium
# 1099                DEU                  high
#
# [1100 rows x 13 columns]

# %%
output = test[['Filename','text', 'Predicted_Language','Predicted_Proficiency']]
output
# Out:
#          Filename                                               text  \
# 0       10226.txt  I agree. Because if I had many academic subjec...
# 1       10229.txt  I DO NOT AGREE WITH THIS STATEMENT BECOUSE , N...
# 2       10392.txt  I am not quite sure about my oppinion on that ...
# 3       10445.txt  It is often said that young people's interest ...
# 4       10535.txt  In mordern society, students always face the d...
# ...           ...                                                ...
# 1095  1175383.txt    There are heated disscussion about that youn...
# 1096  1175412.txt  In my personal opinion young people do not spe...
# 1097  1175488.txt  I believe that people who take risks are succe...
# 1098  1175980.txt  With the rapid progress of time everything aro...
# 1099  1176184.txt  Taking risks and trying new things have in com...
#
#      Predicted_Language Predicted_Proficiency
# 0                   JPN                   low
# 1                   ARA                   low
# 2                   DEU                  high
# 3                   JPN                  high
# 4                   ZHO                  high
# ...                 ...                   ...
# 1095                ZHO                medium
# 1096                HIN                medium
# 1097                TUR                  high
# 1098                TUR                medium
# 1099                DEU                  high
#
# [1100 rows x 4 columns]

# %%
output.to_csv('predictions_output.csv')
